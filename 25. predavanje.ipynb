# %% [markdown]
# # Numerička matematika - 25. predavanje

# %% [markdown]
# ## 1. Metoda konjugiranih gradijenata za kvadratnu funkciju

# %% [markdown]
# U sljedećem predavanju uvodimo smjerove konjugiranih gradijenata, te opisujemo Flecther-Reevesovu metodu kao i neke kvazi-Newtonove metode

# %%
from IPython.lib.display import YouTubeVideo
vid = YouTubeVideo("VweFdY1mIyg")
display(vid)

# %% [markdown]
# Sad ćemo riješiti par zadatka vezano za teoriju prethodnog videa

# %%
vid = YouTubeVideo("4fr5EeycPPo")
display(vid)
